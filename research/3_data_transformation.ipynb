# %%
import os
# %pwd
# Out:
# 'c:\\Users\\sar\\OneDrive\\Desktop\\DataScienceProjectE2E'

# %%
# os.chdir("../")
# %pwd

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass 
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from src.datascience.constant import (
    CONFIG_FILE_PATH,
    PARAMS_FILE_PATH,
    SCHEMA_FILE_PATH
)

from src.datascience.utils.common import read_yaml,create_directories

# %%
class ConfigurationManager:
    def __init__(self,
                 config_filepath=CONFIG_FILE_PATH,
                 params_filepath=PARAMS_FILE_PATH,
                 schema_filepath=SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])
        
        
    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation
        create_directories([config.root_dir])
        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path
        )
        return data_transformation_config

# %%
import os
from src.datascience import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import logging

logger = logging.getLogger(__name__)

class DataTransformation:
    def __init__(self, config):
        self.config = config

        """ Nite : You can add data transformation technique such as scaler , PCA and all
         you can perform all kind of EDA in ML cycle here beppore passing this data to model 
        
         I am only adding train_test_split coz this data is already cleanup
        """

    def train_test_splitting(self):
        data = pd.read_csv(self.config.data_path)

        # Split data into train and test (75%, 25%)
        train, test = train_test_split(
            data,
            test_size=0.25,
            random_state=42
        )

        train.to_csv(
            os.path.join(self.config.root_dir, "train.csv"),
            index=False
        )
        test.to_csv(
            os.path.join(self.config.root_dir, "test.csv"),
            index=False
        )

        logger.info("Splitted data into training and test sets")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config = ConfigurationManager()

    data_transformation_config = config.get_data_transformation_config()

    data_transformation = DataTransformation(
        config=data_transformation_config
    )

    data_transformation.train_test_splitting()

except Exception as e:
    raise e
# Out:
# [2026-01-26 16:57:32,372: INFO: common: YAML file: config\config.yamlloaded successfully from: config\config.yaml]
# [2026-01-26 16:57:32,377: INFO: common: YAML file: params.yamlloaded successfully from: params.yaml]
# [2026-01-26 16:57:32,384: INFO: common: YAML file: schema.yamlloaded successfully from: schema.yaml]
# [2026-01-26 16:57:32,389: INFO: common: created directory at: artifacts]
# [2026-01-26 16:57:32,392: INFO: common: created directory at: artifacts/data_transformationd]
# [2026-01-26 16:57:32,523: INFO: 3593906030: Splitted data into training and test sets]
# [2026-01-26 16:57:32,526: INFO: 3593906030: (1199, 12)]
# [2026-01-26 16:57:32,529: INFO: 3593906030: (400, 12)]
# (1199, 12)
# (400, 12)
